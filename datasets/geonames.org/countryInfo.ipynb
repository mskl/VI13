# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("./countryInfo.txt", delimiter="\t")

# %%
df.sample(15)
# Out:
#     ISO ISO3  ISO-Numeric fips                           Country  \
# 151  MR  MRT          478   MR                        Mauritania
# 189  RO  ROU          642   RO                           Romania
# 73   FO  FRO          234   FO                     Faroe Islands
# 86   GP  GLP          312   GP                        Guadeloupe
# 237  VC  VCT          670   VC  Saint Vincent and the Grenadines
# 80   GG  GGY          831   GK                          Guernsey
# 177  PH  PHL          608   RP                       Philippines
# 249  ZW  ZWE          716   ZI                          Zimbabwe
# 101  IE  IRL          372   EI                           Ireland
# 200  SH  SHN          654   SH                      Saint Helena
# 7    AO  AGO           24   AO                            Angola
# 26   BM  BMU           60   BD                           Bermuda
# 2    AF  AFG            4   AF                       Afghanistan
# ...
